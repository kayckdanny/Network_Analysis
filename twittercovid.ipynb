# %% [markdown]
# <a href="https://colab.research.google.com/github/kayckdanny/Network_Analysis/blob/main/twittercovid.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.0 Introduction

# %% [markdown]
# In this lesson, we use Twitter data to create and explore directed networks of social interactions. For this lesson, we'll be using a developer workflow where we assume you have access to an app's API key and secret (see the slides).
#
#
# Contents:
#
# 1. Introduction
# 2. Authenticating with Twitter's API
# 2. Twitter API basics
# 3. Using Twitter's search API to get tweets of interest
# 4. Creating social network graphs
# 5. Twitter retweet network
# 6. Twitter mention network
#
# ***Copyright:*** *Parts of the contents of this Colab Notebook, unless otherwise indicated, are Copyright 2020 Filippo Menczer, Santo Fortunato and Clayton A. Davis, [A First Course in Network Science](https://github.com/CambridgeUniversityPress/FirstCourseNetworkScience). All rights reserved.*
#
# ***References***: getting started with the Twitter API v2 for academic research [here](https://github.com/twitterdev/getting-started-with-the-twitter-api-v2-for-academic-research).

# %% [markdown]
# # 2.0 Authenticating with Twitter's API

# %% [markdown]
# Twitter uses OAuth in order to allow third-party apps to access data on your behalf without requiring your Twitter login credentials -- note that none of the code in this notebook asks for your Twitter screen name or password.
#
# The OAuth "dance" can be intimidating when you first use it, but it provides a far more secure way for software to make requests on your behalf than providing your username and password.
#
# We'll make use of the
# [Twython](https://twython.readthedocs.io/en/latest/usage/starting_out.html#authentication)
# package to help us with authentication and querying Twitter's APIs.

# %%
# !pip install Twython
# Out:
# Collecting Twython
#   Downloading twython-3.9.1-py3-none-any.whl (33 kB)
# Requirement already satisfied: requests>=2.1.0 in /usr/local/lib/python3.7/dist-packages (from Twython) (2.23.0)
# Requirement already satisfied: requests-oauthlib>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from Twython) (1.3.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.1.0->Twython) (2021.5.30)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.4.0->Twython) (3.1.1)
# Installing collected packages: Twython
# Successfully installed Twython-3.9.1

# %%
from twython import Twython

# %% [markdown]
# ## 2.1 Enter app info and get auth URL

# %% [markdown]
# In order to authenticate with Twitter, we'll provide the app details and  ask for a one-time authorization URL to authenticate your user with this app.
#
# Copy and paste the API key and secret from your Twitter app into a file named <font color="red">keys.txt</font>. The first line is the API_KEY and the second line of the file is API_SECRET_KEY. For example, a template for the <font color="red">keys.txt</font>:
#
# ```python
# df6cf09894907b92f3ea749ef
# d19c40cbb184f72055c806f107b5158d023a43eb7d8921a0d0
# ```

# %%
# open the keys file
my_file = open("keys.txt", "r")

# read the raw data
content = my_file.read()

# split all lines by  newline character
API_KEY, API_SECRET_KEY = content.split("\n")

# close the file
my_file.close()

# %%
print(API_KEY)
# Out:
# NXANBkfeE1IEBvhWplpvOPFIL

# %%
print(f'API KEY = {API_KEY}, API SECRET KEY = {API_SECRET_KEY}')
# Out:
# API KEY = NXANBkfeE1IEBvhWplpvOPFIL, API SECRET KEY = EV9xTproN0mSTBfc4r0Ire6RGHcnwrghzG0xGfKFvzZ1vbPlIx

# %% [markdown]
# Executing the cell should then print out a clickable URL. This link is unique and will work **exactly** once. <font color="red"> Visit this URL, log into Twitter, and then copy the verifier pin that is given to you so as to paste it in the next step</font>.

# %%
twitter = Twython(API_KEY, API_SECRET_KEY)

authentication_tokens = twitter.get_authentication_tokens()
print(authentication_tokens['auth_url'])
# Out:
# https://api.twitter.com/oauth/authenticate?oauth_token=zi5YuQAAAAABTPCAAAABe8-UMzo

# %% [markdown]
# ## 2.2 Authorize app using verifier PIN

# %% [markdown]
# That verifier PIN goes into the next cell. This will be different every time you run these steps. The `authentication_tokens` include temporary tokens that go with this verifier PIN; by submitting these together, we show Twitter that we are who we say we are.

# %%
# Replace the verifier with the pin number obtained with your web browser in the previous step
VERIFIER = '8383568'

twitter = Twython(API_KEY, API_SECRET_KEY,
                  authentication_tokens['oauth_token'],
                  authentication_tokens['oauth_token_secret'])

authorized_tokens = twitter.get_authorized_tokens(VERIFIER)

# %% [markdown]
# ## 2.3 Use authorized tokens

# %% [markdown]
# Now we have a permanent token pair that we can use to make authenticated calls to the Twitter API. We'll create a new Twython object using these authenticated keys and verify the credentials of the logged-in user.

# %%
twitter = Twython(API_KEY, API_SECRET_KEY,
                  authorized_tokens['oauth_token'],
                  authorized_tokens['oauth_token_secret'])

twitter.verify_credentials()
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Fri Apr 24 22:43:20 +0000 2020',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'Maranhense radicado em terras potiguares. Gestor de Políticas Públicas. Mestre em Estudos Urbanos e Regionais. Pesquisador no Governo do Estado do RN.',
#  'entities': {'description': {'urls': []}},
#  'favourites_count': 5935,
#  'follow_request_sent': False,
#  'followers_count': 80,
#  'following': False,
#  'friends_count': 274,
#  'geo_enabled': True,
#  'has_extended_profile': False,
#  'id': 1253816757552394240,
#  'id_str': '1253816757552394240',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 0,
#  'location': '',
#  'name': 'Kayck Danny',
#  'needs_phone_verification': False,
#  'notifications': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1253816757552394240/1587768887',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1253816988658475014/NqAmo1ey_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1253816988658475014/NqAmo1ey_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'KayckDanny',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Sep 10 11:57:15 +0000 2021',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': [{'id': 103127282,
#      'id_str': '103127282',
#      'indices': [0, 13],
#      'name': 'Luiz 🌵LULA2022➀➂',
#      'screen_name': 'luizbssantos'},
#     {'id': 66370407,
#      'id_str': '66370407',
#      'indices': [14, 25],
#      'name': 'Joanna Maranhão',
#      'screen_name': 'Jujuca1987'},
#     {'id': 952134710,
#      'id_str': '952134710',
#      'indices': [26, 36],
#      'name': 'Mano Brown',
#      'screen_name': 'manobrown'},
#     {'id': 2670726740,
#      'id_str': '2670726740',
#      'indices': [37, 49],
#      'name': 'Lula',
#      'screen_name': 'LulaOficial'}]},
#   'favorite_count': 0,
#   'favorited': False,
#   'geo': None,
#   'id': 1436297716204818438,
#   'id_str': '1436297716204818438',
#   'in_reply_to_screen_name': 'luizbssantos',
#   'in_reply_to_status_id': 1436288330522578957,
#   'in_reply_to_status_id_str': '1436288330522578957',
#   'in_reply_to_user_id': 103127282,
#   'in_reply_to_user_id_str': '103127282',
#   'is_quote_status': False,
#   'lang': 'pt',
#   'place': None,
#   'retweet_count': 0,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': '@luizbssantos @Jujuca1987 @manobrown @LulaOficial A minha é mais nova e não sabe. Kkkkk',
#   'truncated': False},
#  'statuses_count': 1252,
#  'suspended': False,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': None,
#  'utc_offset': None,
#  'verified': False,
#  'withheld_in_countries': []}

# %% [markdown]
# If the previous cell ran without error and printed out a dict corresponding to a
# [Twitter User](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/user-object),
# then you're good. The authorized token pair is like a username/password and should be protected as such.

# %% [markdown]
# # 3.0 Twitter API basics

# %% [markdown]
# In this lesson, we'll be dealing with two different types of data, Users and Tweets.

# %% [markdown]
# ## 3.1 User objects

# %% [markdown]
# We've already seen one
# [User Object](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/user-object),
# the one corresponding to the logged-in user, via the call to  `verify_credentials()` above. We can also fetch data for an arbitrary user:

# %%
# fetch data from UFRN's user
user = twitter.show_user(screen_name='CoronavirusBra1')
user
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Thu Jan 30 00:12:49 +0000 2020',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'Notícias do Coronavírus no Brasil e no Mundo.\n\nAcompanhe os casos com o Bot no Telegram: https://t.co/K7jUso8qGO',
#  'entities': {'description': {'urls': [{'display_url': 't.me/coronavirusbrb…',
#      'expanded_url': 'https://t.me/coronavirusbrbot',
#      'indices': [89, 112],
#      'url': 'https://t.co/K7jUso8qGO'}]},
#   'url': {'urls': [{'display_url': 'coronavirusbra1.github.io',
#      'expanded_url': 'https://coronavirusbra1.github.io/',
#      'indices': [0, 23],
#      'url': 'https://t.co/6iW5wLr2S0'}]}},
#  'favourites_count': 3022,
#  'follow_request_sent': False,
#  'followers_count': 252025,
#  'following': True,
#  'friends_count': 157,
#  'geo_enabled': False,
#  'has_extended_profile': True,
#  'id': 1222673964419485696,
#  'id_str': '1222673964419485696',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 519,
#  'location': 'Brasil',
#  'name': 'Coronavírus Brasil',
#  'notifications': False,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': None,
#  'profile_background_image_url_https': None,
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1222673964419485696/1611356873',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1352658143935922178/gVbjGAZZ_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1352658143935922178/gVbjGAZZ_normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_location': None,
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'CoronavirusBra1',
#  'status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Sep 10 00:00:09 +0000 2021',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'coronavirusbra1.github.io',
#      'expanded_url': 'https://coronavirusbra1.github.io',
#      'indices': [21, 44],
#      'url': 'https://t.co/x9VCG4C2EQ'},
#     {'display_url': 'apoia.se/coronavirusbra',
#      'expanded_url': 'https://apoia.se/coronavirusbra',
#      'indices': [85, 108],
#      'url': 'https://t.co/HI1fyEvWfo'}],
#    'user_mentions': []},
#   'favorite_count': 73,
#   'favorited': False,
#   'geo': None,
#   'id': 1436117253792075779,
#   'id_str': '1436117253792075779',
#   'in_reply_to_screen_name': 'CoronavirusBra1',
#   'in_reply_to_status_id': 1436117251585888258,
#   'in_reply_to_status_id_str': '1436117251585888258',
#   'in_reply_to_user_id': 1222673964419485696,
#   'in_reply_to_user_id_str': '1222673964419485696',
#   'is_quote_status': False,
#   'lang': 'pt',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 3,
#   'retweeted': False,
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'text': 'Divisão por estados: https://t.co/x9VCG4C2EQ \n\nContribua com a manutenção do painel: https://t.co/HI1fyEvWfo',
#   'truncated': False},
#  'statuses_count': 9888,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': 'https://t.co/6iW5wLr2S0',
#  'utc_offset': None,
#  'verified': True,
#  'withheld_in_countries': []}

# %% [markdown]
# This dictionary of user data contains several items of note. First, the screen name of the user, while obvious in this case, is very useful later:

# %%
user['screen_name']
# Out:
# 'CoronavirusBra1'

# %% [markdown]
# The user data also contains information such as the number of followers, friends (other users followerd by this user), and tweets (called `'statuses'` in the API):

# %%
print("""
Twitter user @{screen_name}
has {followers_count} followers,
follows {friends_count} users,
and has tweeted {statuses_count} times.
""".format(**user))
# Out:
# Twitter user @CoronavirusBra1
# has 252025 followers,
# follows 157 users,
# and has tweeted 9888 times.

# %% [markdown]
# ### 3.1.1 Playing with followeres with Twython

# %% [markdown]
# It doesn’t need to be said that **Followers** are, and should be, the driving force behind your social success on Twitter. You need to make your **Followers** feel special for Following you. And you need to get as much information about them as possible, so you can analyse your follower demographics for further analysis and targeting. So you can find out exactly how you can make them feel even more special! And feel that following you is worthwhile….
#
# But before you can do any of that, <font color="red"> you first need to get some idea of who your followers are</font>. So let’s start on the basics!
#
# - GET followers/list [documentation](https://developer.twitter.com/en/docs/twitter-api/v1/accounts-and-users/follow-search-get-users/api-reference/get-followers-list).

# %%
# there are some rate limitations in order to use the Twitter API
# you can see the current limits calling get_applicaiton_rate_limit_status()
twitter.get_application_rate_limit_status()['resources']
# Out:
# {'account': {'/account/authenticate_web_view': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/account/change_password': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account/login_verification_enrollment': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account/settings': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/account/update_profile': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account/verify_credentials': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160}},
#  'account_activity': {'/account_activity/all/:instance_name/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160},
#   '/account_activity/all/:instance_name/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account_activity/all/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account_activity/direct_messages/:instance_name/subscriptions': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account_activity/direct_messages/:instance_name/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account_activity/direct_messages/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account_activity/webhooks': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160},
#   '/account_activity/webhooks/:id/subscriptions/all': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160},
#   '/account_activity/webhooks/:id/subscriptions/all/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/account_activity/webhooks/:id/subscriptions/direct_messages': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160},
#   '/account_activity/webhooks/:id/subscriptions/direct_messages/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'admin_users': {'/admin_users': {'limit': 2000,
#    'remaining': 2000,
#    'reset': 1631278160}},
#  'application': {'/application/rate_limit_status': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160}},
#  'auth': {'/auth/csrf_token': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'blocks': {'/blocks/ids': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/blocks/list': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'business_experience': {'/business_experience/dashboard_features': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/business_experience/dashboard_settings/destroy': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/business_experience/dashboard_settings/show': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/business_experience/dashboard_settings/update': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/business_experience/keywords': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160}},
#  'collections': {'/collections/entries': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160},
#   '/collections/list': {'limit': 1000, 'remaining': 1000, 'reset': 1631278160},
#   '/collections/show': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160}},
#  'compliance': {'/compliance/jobs&GET': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631278160},
#   '/compliance/jobs&POST': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631278160},
#   '/compliance/jobs/:job_id': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631278160}},
#  'contacts': {'/contacts/addressbook': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/contacts/delete/status': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/contacts/uploaded_by': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/contacts/users': {'limit': 300, 'remaining': 300, 'reset': 1631278160},
#   '/contacts/users_and_uploaded_by': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160}},
#  'custom_profiles': {'/custom_profiles/list': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/custom_profiles/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160}},
#  'device': {'/device/token': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'direct_messages': {'/direct_messages': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/direct_messages/broadcasts/list': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631278160},
#   '/direct_messages/broadcasts/show': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631278160},
#   '/direct_messages/broadcasts/statuses/list': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631278160},
#   '/direct_messages/broadcasts/statuses/show': {'limit': 60,
#    'remaining': 60,
#    'reset': 1631278160},
#   '/direct_messages/events/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/direct_messages/events/show': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/direct_messages/mark_read': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160},
#   '/direct_messages/sent': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/direct_messages/sent_and_received': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/direct_messages/show': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/direct_messages/subscribers/ids': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/direct_messages/subscribers/lists/list': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/direct_messages/subscribers/lists/members/ids': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/direct_messages/subscribers/lists/members/show': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160},
#   '/direct_messages/subscribers/lists/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/direct_messages/subscribers/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160}},
#  'drafts': {'/drafts/statuses/create': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/drafts/statuses/destroy': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/drafts/statuses/ids': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/drafts/statuses/list': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/drafts/statuses/show': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/drafts/statuses/update': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160}},
#  'favorites': {'/favorites/list': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160}},
#  'feedback': {'/feedback/events': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160},
#   '/feedback/show/:id': {'limit': 180, 'remaining': 180, 'reset': 1631278160}},
#  'fleets': {'/fleets/:version/avatar_content': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160},
#   '/fleets/:version/create': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/fleets/:version/delete': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/fleets/:version/feedback/create': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160},
#   '/fleets/:version/fleet_threads': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160},
#   '/fleets/:version/fleetline': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160},
#   '/fleets/:version/home_timeline': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160},
#   '/fleets/:version/mark_read': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160},
#   '/fleets/:version/mutes/create': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160},
#   '/fleets/:version/mutes/destroy': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160},
#   '/fleets/:version/mutes/list': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160},
#   '/fleets/:version/track_events': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160},
#   '/fleets/:version/update': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/fleets/:version/user_fleets': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/fleets/:version/viewers': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160}},
#  'followers': {'/followers/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'friends': {'/friends/following/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/friends/following/list': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/friends/ids': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/friends/list': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'friendships': {'/friendships/incoming': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/friendships/list': {'limit': 200, 'remaining': 200, 'reset': 1631278160},
#   '/friendships/lookup': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/friendships/no_retweets/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/friendships/outgoing': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/friendships/show': {'limit': 180, 'remaining': 180, 'reset': 1631278160}},
#  'geo': {'/geo/id/:place_id': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/geo/place_page': {'limit': 75, 'remaining': 75, 'reset': 1631278160},
#   '/geo/reverse_geocode': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/geo/search': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/geo/similar_places': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'graphql': {'/graphql': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'graphql&POST': {'/graphql&POST': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'guide': {'/guide': {'limit': 180, 'remaining': 180, 'reset': 1631278160},
#   '/guide/explore_locations_with_autocomplete': {'limit': 200,
#    'remaining': 200,
#    'reset': 1631278160},
#   '/guide/get_explore_locations': {'limit': 100,
#    'remaining': 100,
#    'reset': 1631278160}},
#  'help': {'/help/configuration': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/help/languages': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/help/privacy': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/help/settings': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/help/tos': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'i': {'/i/config': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/i/tfb/v1/smb/web/:account_id/payment/save': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'labs': {'/labs/2/platform_manipulation/reports': {'limit': 5,
#    'remaining': 5,
#    'reset': 1631278160},
#   '/labs/2/reports': {'limit': 5, 'remaining': 5, 'reset': 1631278160},
#   '/labs/:version/tweets/*': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631278160},
#   '/labs/:version/tweets/:id/hidden&PUT': {'limit': 10,
#    'remaining': 10,
#    'reset': 1631278160},
#   '/labs/:version/tweets/metrics/private': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/labs/:version/tweets/search': {'limit': 225,
#    'remaining': 225,
#    'reset': 1631278160},
#   '/labs/:version/tweets/stream/compliance': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160},
#   '/labs/:version/tweets/stream/filter/': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/labs/:version/tweets/stream/filter/:instance_name': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/labs/:version/tweets/stream/filter/rules&POST': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/labs/:version/tweets/stream/filter/rules/': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/labs/:version/tweets/stream/filter/rules/:instance_name': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/labs/:version/tweets/stream/sample': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/labs/:version/users/*': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631278160},
#   '/labs/:version/users/:id/tweets': {'limit': 225,
#    'remaining': 225,
#    'reset': 1631278160},
#   '/labs/:version/users/by/username/:handle/tweets': {'limit': 225,
#    'remaining': 225,
#    'reset': 1631278160}},
#  'limiter_scalding_report_creation': {'/limiter_scalding_report_creation': {'limit': 4500,
#    'remaining': 4500,
#    'reset': 1631278160}},
#  'lists': {'/lists/list': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/lists/members': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/lists/members/show': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/lists/memberships': {'limit': 75, 'remaining': 75, 'reset': 1631278160},
#   '/lists/ownerships': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/lists/show': {'limit': 75, 'remaining': 75, 'reset': 1631278160},
#   '/lists/statuses': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/lists/subscribers': {'limit': 180, 'remaining': 180, 'reset': 1631278160},
#   '/lists/subscribers/show': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/lists/subscriptions': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'live_pipeline': {'/live_pipeline/events': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160}},
#  'live_video_stream': {'/live_video_stream/status/:id': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160}},
#  'media': {'/media/upload': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160}},
#  'moments': {'/moments/create': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/moments/permissions': {'limit': 300,
#    'remaining': 300,
#    'reset': 1631278160},
#   '/moments/statuses/update': {'limit': 5,
#    'remaining': 5,
#    'reset': 1631278160}},
#  'mutes': {'/mutes/users/ids': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/mutes/users/list': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'oauth': {'/oauth/invalidate_token': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/oauth/revoke': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/oauth/revoke_html': {'limit': 15, 'remaining': 15, 'reset': 1631278160}},
#  'paseto': {'/paseto/token': {'limit': 25,
#    'remaining': 25,
#    'reset': 1631278160}},
#  'permissions': {'/permissions/user_permissions': {'limit': 3,
#    'remaining': 3,
#    'reset': 1631278160},
#   '/permissions/user_permissions/admin_email_verification': {'limit': 3,
#    'remaining': 3,
#    'reset': 1631278160}},
#  'safety': {'/safety/detection_feedback': {'limit': 450000,
#    'remaining': 450000,
#    'reset': 1631278160}},
#  'sandbox': {'/sandbox/account_activity/webhooks/:id/subscriptions': {'limit': 500,
#    'remaining': 500,
#    'reset': 1631278160}},
#  'saved_searches': {'/saved_searches/destroy/:id': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/saved_searches/list': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/saved_searches/show/:id': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'search': {'/search/tweets': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160}},
#  'statuses': {'/statuses/friends': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/statuses/home_timeline': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/statuses/lookup': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/statuses/mentions_timeline': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/statuses/oembed': {'limit': 180, 'remaining': 180, 'reset': 1631278160},
#   '/statuses/retweeters/ids': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/statuses/retweets/:id': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/statuses/retweets_of_me': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/statuses/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/statuses/user_timeline': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631278160}},
#  'strato': {'/strato/column/None/:id/cms/*': {'limit': 150,
#    'remaining': 150,
#    'reset': 1631278160}},
#  'teams': {'/teams/authorize': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'traffic': {'/traffic/map': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'trends': {'/trends/available': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/trends/closest': {'limit': 75, 'remaining': 75, 'reset': 1631278160},
#   '/trends/place': {'limit': 75, 'remaining': 75, 'reset': 1631278160}},
#  'tweet_prompts': {'/tweet_prompts/report_interaction': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/tweet_prompts/show': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160}},
#  'tweets': {'/tweets/': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/tweets/:id': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/tweets/:id&DELETE': {'limit': 50, 'remaining': 50, 'reset': 1631278160},
#   '/tweets/:id/hidden&PUT': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/tweets/:id/retweeted_by': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/tweets/:tweet_id/liking_users': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/tweets/counts/all': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/tweets/counts/recent': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631278160},
#   '/tweets/sample/stream': {'limit': 50, 'remaining': 50, 'reset': 1631278160},
#   '/tweets/search/:product/:instance/counts': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631278160},
#   '/tweets/search/:product/:label': {'limit': 1800,
#    'remaining': 1800,
#    'reset': 1631278160},
#   '/tweets/search/all': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/tweets/search/recent': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/tweets/search/stream': {'limit': 50, 'remaining': 50, 'reset': 1631278160},
#   '/tweets/search/stream/rules': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/tweets/search/stream/rules&DELETE': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/tweets/search/stream/rules&POST': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160},
#   '/tweets/search/stream/rules/validation&POST': {'limit': 450,
#    'remaining': 450,
#    'reset': 1631278160}},
#  'tweets&POST': {'/tweets&POST': {'limit': 200,
#    'remaining': 200,
#    'reset': 1631278160}},
#  'users': {'/users/': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/users/:id': {'limit': 900, 'remaining': 899, 'reset': 1631278133},
#   '/users/:id/blocking': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/users/:id/blocking&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:id/followers': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/users/:id/following': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/users/:id/liked_tweets': {'limit': 75,
#    'remaining': 75,
#    'reset': 1631278160},
#   '/users/:id/likes&POST': {'limit': 50, 'remaining': 50, 'reset': 1631278160},
#   '/users/:id/likes/:tweet_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:id/mentions': {'limit': 180, 'remaining': 180, 'reset': 1631278160},
#   '/users/:id/muting&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:id/retweets&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:id/retweets/:source_tweet_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:id/tweets': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/users/:source_user_id/blocking/:target_user_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:source_user_id/following&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:source_user_id/following/:target_user_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/:source_user_id/muting/:target_user_id&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/by': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/users/by/username/:handle/mentions': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/users/by/username/:handle/tweets': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631278160},
#   '/users/by/username/:source_username/following&POST': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/by/username/:source_username/following/:target_user_name&DELETE': {'limit': 50,
#    'remaining': 50,
#    'reset': 1631278160},
#   '/users/by/username/:username': {'limit': 900,
#    'remaining': 900,
#    'reset': 1631278160},
#   '/users/by/username/:username/followers': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/users/by/username/:username/following': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/users/contributees/pending': {'limit': 200,
#    'remaining': 200,
#    'reset': 1631278160},
#   '/users/contributors/pending': {'limit': 2000,
#    'remaining': 2000,
#    'reset': 1631278160},
#   '/users/derived_info': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/users/lookup': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/users/profile_banner': {'limit': 180,
#    'remaining': 180,
#    'reset': 1631278160},
#   '/users/report_spam': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/users/search': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/users/show/:id': {'limit': 900, 'remaining': 900, 'reset': 1631278160},
#   '/users/suggestions': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/users/suggestions/:slug': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/users/suggestions/:slug/members': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'verify': {'/verify/:version/access': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/verify/:version/account-eligibility': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/verify/:version/badge-violation': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/verify/:version/badge-violation/violations': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/verify/:version/document-formats': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/verify/:version/id-document&GET': {'limit': 1000,
#    'remaining': 1000,
#    'reset': 1631278160},
#   '/verify/:version/id-document&POST': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160},
#   '/verify/:version/intake': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}},
#  'webhooks': {'/webhooks': {'limit': 15, 'remaining': 15, 'reset': 1631278160},
#   '/webhooks/subscriptions/direct_messages': {'limit': 15,
#    'remaining': 15,
#    'reset': 1631278160}}}

# %%
# current limits to followers/list endpoint
twitter.get_application_rate_limit_status()['resources']['followers']
# Out:
# {'/followers/ids': {'limit': 15, 'remaining': 15, 'reset': 1631278166},
#  '/followers/list': {'limit': 15, 'remaining': 15, 'reset': 1631278166}}

# %%
# During the writing of this notebook Coronavirus twitter user has
# 15507 followers. So, at maximum is possible to retrieve 200 x 15 followers in just a call.
# Thus, considering only 15 calls are allowed during a window of 15 min
# it will be necessary at least 6 calls to collect all UFRN followers
# 6 calls x 15min = 90min!!!!
15507/(200 * 15)
# Out:
# 5.169

# %%
import datetime
import pandas as pd

# We need to create empty lists for each of those user characteristics
names = []
usernames = []
ids = []
locations = []
follower_count = []

# Getting today's date
datestamp = datetime.datetime.now().strftime("%Y-%m-%d")

# Asking for the username to get their followers
username = 'CoronavirusBra1'

# This is to go through paginated results
next_cursor = -1

# %%
# Let's try 10 calls (limit is 15), 200 x 10 = 2000 followers
for i in range(10):
  # Getting the user's followers (should all be 1 line)
  # Note that are rate limited in API, see the documentation above.
  get_followers = twitter.get_followers_list(screen_name=username,
                                             count=200,
                                             cursor=next_cursor)
  # For each user returned from our get_followers
  for follower in get_followers["users"]:
      names.append(follower["name"])
      usernames.append(follower["screen_name"])
      ids.append(follower["id"])
      locations.append(follower["location"])
      follower_count.append(follower["followers_count"])
  # next cursor
  next_cursor = get_followers["next_cursor"]

# %%
# for the sake of understanding check again
# current limits to followers/list endpoint
twitter.get_application_rate_limit_status()['resources']['followers']
# Out:
# {'/followers/ids': {'limit': 15, 'remaining': 15, 'reset': 1631278237},
#  '/followers/list': {'limit': 15, 'remaining': 5, 'reset': 1631278185}}

# %%
# create a dataframe using ufrn's followers
df = pd.DataFrame.from_dict({"display_name": names,
                             "username": usernames,
                             "user_id": ids,
                             "location": locations,
                             "followers_count": follower_count})

# check the dataframe
df.head()
# Out:
#                display_name         username  ...       location followers_count
# 0             Real.finanças       Real_davi1  ...                              0
# 1           Tânia Savariego   SavariegoTania  ...  Curitiba - PR               7
# 2  sunnymirelli@hotmail.com     sunnymirelli  ...                              0
# 3         ALESSANDRA SANTOS   ALESSANDRATONE  ...                              0
# 4          Roselea Ferreira  RoseleaFerreir1  ...                              0
#
# [5 rows x 5 columns]

# %%
# save to a csv file
df.to_csv(username+"-"+datestamp+".csv")

# %% [markdown]
# ## 3.2 Tweet Objects

# %% [markdown]
# The second type of data of which we will make use is the
# [Tweet Object](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object).
# A user object actually contains the user's most recent tweet:

# %%
# fetch data from CoronavirusBra1 user
user = twitter.show_user(screen_name='CoronavirusBra1')

# %%
most_recent_tweet = user['status']
most_recent_tweet
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Sep 10 00:00:09 +0000 2021',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'coronavirusbra1.github.io',
#     'expanded_url': 'https://coronavirusbra1.github.io',
#     'indices': [21, 44],
#     'url': 'https://t.co/x9VCG4C2EQ'},
#    {'display_url': 'apoia.se/coronavirusbra',
#     'expanded_url': 'https://apoia.se/coronavirusbra',
#     'indices': [85, 108],
#     'url': 'https://t.co/HI1fyEvWfo'}],
#   'user_mentions': []},
#  'favorite_count': 73,
#  'favorited': False,
#  'geo': None,
#  'id': 1436117253792075779,
#  'id_str': '1436117253792075779',
#  'in_reply_to_screen_name': 'CoronavirusBra1',
#  'in_reply_to_status_id': 1436117251585888258,
#  'in_reply_to_status_id_str': '1436117251585888258',
#  'in_reply_to_user_id': 1222673964419485696,
#  'in_reply_to_user_id_str': '1222673964419485696',
#  'is_quote_status': False,
#  'lang': 'pt',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 3,
#  'retweeted': False,
#  'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#  'text': 'Divisão por estados: https://t.co/x9VCG4C2EQ \n\nContribua com a manutenção do painel: https://t.co/HI1fyEvWfo',
#  'truncated': False}

# %% [markdown]
# Tweet objects contain several interesting data and metadata, but the most basic are the `'text'` and `'entities'`. The `'text'` is what you expect it to be: the text of the tweet:

# %%
most_recent_tweet['text']
# Out:
# 'Divisão por estados: https://t.co/x9VCG4C2EQ \n\nContribua com a manutenção do painel: https://t.co/HI1fyEvWfo'

# %% [markdown]
# The `'entities'` field contains several tokens of interest already extracted from the tweet such as hashtags, URLs, images, and mentions of other users:

# %%
most_recent_tweet['entities']
# Out:
# {'hashtags': [],
#  'symbols': [],
#  'urls': [{'display_url': 'coronavirusbra1.github.io',
#    'expanded_url': 'https://coronavirusbra1.github.io',
#    'indices': [21, 44],
#    'url': 'https://t.co/x9VCG4C2EQ'},
#   {'display_url': 'apoia.se/coronavirusbra',
#    'expanded_url': 'https://apoia.se/coronavirusbra',
#    'indices': [85, 108],
#    'url': 'https://t.co/HI1fyEvWfo'}],
#  'user_mentions': []}

# %% [markdown]
# In particular, we'll make use of the `'user_mentions'` later:

# %%
most_recent_tweet['entities']['user_mentions']
# Out:
# []

# %% [markdown]
# # 4.0 Using Twitter's search API to get tweets of interest

# %% [markdown]
# Twitter's
# [Search API](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html)
# allows you to fetch recent tweets according to a query of keywords, URLs, hashtags, user mentions, etc.

# %% [markdown]
# ## 4.1 Get tweets matching a hashtag
#
# We'll make use of the ability to search by hashtags:

# %%
search_response = twitter.search(q='#covid19', count=100)

# %%
search_response
# Out:
# {'search_metadata': {'completed_in': 0.154,
#   'count': 100,
#   'max_id': 1436307635368833031,
#   'max_id_str': '1436307635368833031',
#   'next_results': '?max_id=1436307463733612549&q=%23covid19&count=100&include_entities=1',
#   'query': '%23covid19',
#   'refresh_url': '?since_id=1436307635368833031&q=%23covid19&include_entities=1',
#   'since_id': 0,
#   'since_id_str': '0'},
#  'statuses': [{'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:40 +0000 2021',
#    'entities': {'hashtags': [{'indices': [0, 8], 'text': 'Covid19'}],
#     'symbols': [],
#     'urls': [{'display_url': 'lalsace.fr/sante/2021/09/…',
#       'expanded_url': 'https://www.lalsace.fr/sante/2021/09/10/des-chercheurs-parviennent-a-detecter-le-virus-dans-la-sueur?utm_medium=Social&utm_source=Twitter#Echobox=1631263974-1',
#       'indices': [73, 96],
#       'url': 'https://t.co/RRn1RkwSmw'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307635368833031,
#    'id_str': '1436307635368833031',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'fr',
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://www.echobox.com" rel="nofollow">Echobox</a>',
#    'text': '#Covid19 Des chercheurs parviennent à détecter le virus... dans la sueur https://t.co/RRn1RkwSmw',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Apr 15 15:25:01 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': "Toute l'actualité de la région",
#     'entities': {'description': {'urls': []},
#      'url': {'urls': [{'display_url': 'lalsace.fr',
#         'expanded_url': 'https://lalsace.fr/',
#         'indices': [0, 23],
#         'url': 'https://t.co/JxV66VNa5G'}]}},
#     'favourites_count': 77,
#     'follow_request_sent': False,
#     'followers_count': 98194,
#     'following': False,
#     'friends_count': 734,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 31432523,
#     'id_str': '31432523',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 839,
#     'location': 'Alsace, France',
#     'name': "Journal L'Alsace",
#     'notifications': False,
#     'profile_background_color': 'ABB8C2',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/31432523/1453977186',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1284028649184911362/Tjbc8k8C_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1284028649184911362/Tjbc8k8C_normal.jpg',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': 'C6E2EE',
#     'profile_sidebar_fill_color': 'DAECF4',
#     'profile_text_color': '663B12',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'lalsace',
#     'statuses_count': 58112,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'https://t.co/JxV66VNa5G',
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:40 +0000 2021',
#    'entities': {'hashtags': [{'indices': [72, 80], 'text': 'Covid19'},
#      {'indices': [98, 104], 'text': 'Miami'}],
#     'symbols': [],
#     'urls': [{'display_url': 'bit.ly/3EebMzg',
#       'expanded_url': 'https://bit.ly/3EebMzg',
#       'indices': [107, 130],
#       'url': 'https://t.co/BXjswYWt4i'}],
#     'user_mentions': [{'id': 23377748,
#       'id_str': '23377748',
#       'indices': [3, 18],
#       'name': 'Azteca Noticias',
#       'screen_name': 'AztecaNoticias'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307635326783489,
#    'id_str': '1436307635326783489',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 10 11:30:00 +0000 2021',
#     'entities': {'hashtags': [{'indices': [52, 60], 'text': 'Covid19'},
#       {'indices': [78, 84], 'text': 'Miami'}],
#      'symbols': [],
#      'urls': [{'display_url': 'bit.ly/3EebMzg',
#        'expanded_url': 'https://bit.ly/3EebMzg',
#        'indices': [87, 110],
#        'url': 'https://t.co/BXjswYWt4i'}],
#      'user_mentions': []},
#     'favorite_count': 2,
#     'favorited': False,
#     'geo': None,
#     'id': 1436290858085752832,
#     'id_str': '1436290858085752832',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#     'text': 'TIENEN UN OLFATO AGUDO \n\nPerros entrenados detectan #Covid19 en aeropuerto de #Miami \n\nhttps://t.co/BXjswYWt4i',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Mar 09 00:35:31 +0000 2009',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Ponte al día con nuestras noticias. También puedes seguirnos en https://t.co/iqrXKsA5Kj',
#      'entities': {'description': {'urls': [{'display_url': 'facebook.com/AztecaNoticias',
#          'expanded_url': 'http://www.facebook.com/AztecaNoticias',
#          'indices': [64, 87],
#          'url': 'https://t.co/iqrXKsA5Kj'}]},
#       'url': {'urls': [{'display_url': 'aztecanoticias.com.mx',
#          'expanded_url': 'http://www.aztecanoticias.com.mx',
#          'indices': [0, 23],
#          'url': 'https://t.co/7UTCzXk7uN'}]}},
#      'favourites_count': 689,
#      'follow_request_sent': False,
#      'followers_count': 708366,
#      'following': False,
#      'friends_count': 722,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 23377748,
#      'id_str': '23377748',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 2824,
#      'location': 'México',
#      'name': 'Azteca Noticias',
#      'notifications': False,
#      'profile_background_color': '4C4A4B',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/23377748/1623040300',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1331841499743469568/J3tjXurx_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1331841499743469568/J3tjXurx_normal.jpg',
#      'profile_link_color': '003042',
#      'profile_sidebar_border_color': 'FFFFFF',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '1A2530',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'AztecaNoticias',
#      'statuses_count': 355521,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/7UTCzXk7uN',
#      'utc_offset': None,
#      'verified': True,
#      'withheld_in_countries': []}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @AztecaNoticias: TIENEN UN OLFATO AGUDO \n\nPerros entrenados detectan #Covid19 en aeropuerto de #Miami \n\nhttps://t.co/BXjswYWt4i',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon Sep 21 20:34:22 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': 'Conductora de Noticias en TV Azteca Puebla #Dancer #WorkingMom Contacto: yuliana.escobedo.tv@gmail.com',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 32142,
#     'follow_request_sent': False,
#     'followers_count': 14126,
#     'following': False,
#     'friends_count': 1105,
#     'geo_enabled': True,
#     'has_extended_profile': True,
#     'id': 76135015,
#     'id_str': '76135015',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 135,
#     'location': '',
#     'name': 'Yuliana Escobedo',
#     'notifications': False,
#     'profile_background_color': '1A1B1F',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/76135015/1506631821',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1359371505507868673/A5pyUywM_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1359371505507868673/A5pyUywM_normal.jpg',
#     'profile_link_color': 'AC0EEB',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '453D66',
#     'profile_text_color': 'FFFFFF',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'YulianaEscobedo',
#     'statuses_count': 46079,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:40 +0000 2021',
#    'entities': {'hashtags': [{'indices': [81, 89], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307634634862595,
#    'id_str': '1436307634634862595',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Anyone know if I have to wait 2 weeks after I get my 2nd covid jab to go abroad? #COVID19',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Dec 05 13:00:48 +0000 2018',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Movies, Man United and Manchester tunes. TRA',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 12561,
#     'follow_request_sent': False,
#     'followers_count': 1311,
#     'following': False,
#     'friends_count': 962,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1070301963986894848,
#     'id_str': '1070301963986894848',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 1,
#     'location': 'Manchester, England',
#     'name': 'Lauren',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1070301963986894848/1630084152',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1431586577558425600/XuWcSA4__normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1431586577558425600/XuWcSA4__normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'LaurenMufc20',
#     'statuses_count': 1773,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:39 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 18536738,
#       'id_str': '18536738',
#       'indices': [3, 14],
#       'name': 'Norm Di Pasquale Spadina-Fort York NDP Candidate',
#       'screen_name': 'normsworld'},
#      {'id': 253340075,
#       'id_str': '253340075',
#       'indices': [17, 33],
#       'name': 'Jagmeet Singh',
#       'screen_name': 'theJagmeetSingh'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307632881602564,
#    'id_str': '1436307632881602564',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 10 12:29:45 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436305896133570583',
#        'indices': [116, 139],
#        'url': 'https://t.co/7QygdwzLSc'}],
#      'user_mentions': [{'id': 253340075,
#        'id_str': '253340075',
#        'indices': [1, 17],
#        'name': 'Jagmeet Singh',
#        'screen_name': 'theJagmeetSingh'}]},
#     'favorite_count': 1,
#     'favorited': False,
#     'geo': None,
#     'id': 1436305896133570583,
#     'id_str': '1436305896133570583',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#     'text': '.@theJagmeetSingh on CBC now, saying we must waive vaccine patent protection so that all countries can manufacture… https://t.co/7QygdwzLSc',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Thu Jan 01 21:27:12 +0000 2009',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Spadina-Fort York NDP Candidate | @TCDSB Trustee Ward 9 (@NormTCDSB) | Chair @NoJetsTO | he/him #SpaFY #cdnpoli #elxn44 #HousingForAll norm.di.pasquale@ndp.ca',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'normdipasquale.ndp.ca',
#          'expanded_url': 'http://normdipasquale.ndp.ca',
#          'indices': [0, 23],
#          'url': 'https://t.co/xcFFB6k1UQ'}]}},
#      'favourites_count': 66476,
#      'follow_request_sent': False,
#      'followers_count': 9117,
#      'following': False,
#      'friends_count': 7091,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 18536738,
#      'id_str': '18536738',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 105,
#      'location': 'Toronto',
#      'name': 'Norm Di Pasquale Spadina-Fort York NDP Candidate',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18536738/1629041320',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1426928834524372997/FpJO6VXu_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1426928834524372997/FpJO6VXu_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'normsworld',
#      'statuses_count': 149529,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/xcFFB6k1UQ',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @normsworld: .@theJagmeetSingh on CBC now, saying we must waive vaccine patent protection so that all countries can manufacture the vacc…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Oct 07 00:18:12 +0000 2010',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'M.A. Sociology; free public transit and the right to the city - He/Him',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 1134,
#     'follow_request_sent': False,
#     'followers_count': 612,
#     'following': False,
#     'friends_count': 713,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 199486091,
#     'id_str': '199486091',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 4,
#     'location': 'Toronto, Ontario',
#     'name': 'Ari Vangeest',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/199486091/1494736775',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1140072824968757255/lqsg4I4v_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1140072824968757255/lqsg4I4v_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'arivangeest',
#     'statuses_count': 325,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:39 +0000 2021',
#    'entities': {'hashtags': [{'indices': [24, 42],
#       'text': 'NouvelleCalédonie'},
#      {'indices': [76, 84], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1436307632688672783',
#       'indices': [117, 140],
#       'url': 'https://t.co/ZI6XsIZxTA'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307632688672783,
#    'id_str': '1436307632688672783',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'fr',
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'text': '🇳🇨 Jusqu’à ce lundi, la #NouvelleCalédonie était préservée de l’épidémie de #COVID19.\n\n👉 Un homme de 75 ans y est d… https://t.co/ZI6XsIZxTA',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Sep 29 19:59:38 +0000 2020',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': "L'actualité nationale/internationale📱. @MediaFrance24\n\nL'information du bout des doigts 📲.\n\nN'oubliez pas de ❤ et de 🔃.",
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 278,
#     'follow_request_sent': False,
#     'followers_count': 1387,
#     'following': False,
#     'friends_count': 73,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1311032864759308290,
#     'id_str': '1311032864759308290',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 19,
#     'location': 'France ',
#     'name': 'MediaFrance24 🌐',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1311032864759308290/1629484514',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1429432629867208713/L3FcMCNo_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1429432629867208713/L3FcMCNo_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'MediaFrance24',
#     'statuses_count': 12296,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:38 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1436307629748465685',
#       'indices': [117, 140],
#       'url': 'https://t.co/oNLOOG5Bz6'}],
#     'user_mentions': []},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307629748465685,
#    'id_str': '1436307629748465685',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'ru',
#    'metadata': {'iso_language_code': 'ru', 'result_type': 'recent'},
#    'place': None,
#    'possibly_sensitive': False,
#    'retweet_count': 0,
#    'retweeted': False,
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': 'COVID-19 в Петербурге за семь дней: 2021-09-04 — 2021-09-10 / 2021-08-28 — 2021-09-03. Выявлено: 8481 / 7865 (107.8… https://t.co/oNLOOG5Bz6',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Oct 29 10:43:16 +0000 2019',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'There is no such thing as an ex-entomologist but presently I am more of a Historian of Science and Education, adept of Digital Humanities and Data analyst.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 43,
#     'follow_request_sent': False,
#     'followers_count': 30,
#     'following': False,
#     'friends_count': 62,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1189130249889558529,
#     'id_str': '1189130249889558529',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': '',
#     'name': 'alexei.kouprianov',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1189130897431416837/a19rIRrW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1189130897431416837/a19rIRrW_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'AKouprianov',
#     'statuses_count': 91,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:37 +0000 2021',
#    'entities': {'hashtags': [{'indices': [52, 60], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1193721035490807808,
#       'id_str': '1193721035490807808',
#       'indices': [3, 17],
#       'name': 'Dr Francisco Moreno Sánchez',
#       'screen_name': 'DrPacoMoreno1'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307625843568644,
#    'id_str': '1436307625843568644',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'es',
#    'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1223,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Sep 09 20:58:48 +0000 2021',
#     'entities': {'hashtags': [{'indices': [33, 41], 'text': 'COVID19'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436071614853140483',
#        'indices': [117, 140],
#        'url': 'https://t.co/Cl6qcNZrQx'}],
#      'user_mentions': []},
#     'favorite_count': 2809,
#     'favorited': False,
#     'geo': None,
#     'id': 1436071614853140483,
#     'id_str': '1436071614853140483',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'es',
#     'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1223,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'Es evidente que la infección por #COVID19 ha cambiado a partir de la aparición de variantes. La estrategia para pro… https://t.co/Cl6qcNZrQx',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Mon Nov 11 02:44:19 +0000 2019',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Médico Internista e Infectólogo.  Premio Nacional de Salud 2020.\nMis tuits son a título personal.',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 363,
#      'follow_request_sent': False,
#      'followers_count': 148372,
#      'following': False,
#      'friends_count': 193,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 1193721035490807808,
#      'id_str': '1193721035490807808',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 403,
#      'location': '',
#      'name': 'Dr Francisco Moreno Sánchez',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1354857078280617986/N-8Nv383_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1354857078280617986/N-8Nv383_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'DrPacoMoreno1',
#      'statuses_count': 1214,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @DrPacoMoreno1: Es evidente que la infección por #COVID19 ha cambiado a partir de la aparición de variantes. La estrategia para proteger…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Tue Nov 07 22:17:31 +0000 2017',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#eddy_talks #MxUnido; ExATec y apartidista, no me van las medias tintas, toma antiácidos antes de leerme.',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 26671,
#     'follow_request_sent': False,
#     'followers_count': 2053,
#     'following': False,
#     'friends_count': 2707,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 928023636392464384,
#     'id_str': '928023636392464384',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 2,
#     'location': 'Raleigh, NC',
#     'name': 'Eddy Talks🔥',
#     'notifications': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/928023636392464384/1627168989',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1424138630163886080/c37QPuoF_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1424138630163886080/c37QPuoF_normal.jpg',
#     'profile_link_color': '1B95E0',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'protected': False,
#     'screen_name': 'Eddy_Talks',
#     'statuses_count': 41463,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:37 +0000 2021',
#    'entities': {'hashtags': [{'indices': [26, 35], 'text': 'BioNTech'},
#      {'indices': [61, 68], 'text': 'Pfizer'},
#      {'indices': [108, 116], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 15392486,
#       'id_str': '15392486',
#       'indices': [3, 14],
#       'name': 'Disclose.tv',
#       'screen_name': 'disclosetv'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307625059274752,
#    'id_str': '1436307625059274752',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 736,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 10 11:36:38 +0000 2021',
#     'entities': {'hashtags': [{'indices': [10, 19], 'text': 'BioNTech'},
#       {'indices': [45, 52], 'text': 'Pfizer'},
#       {'indices': [92, 100], 'text': 'COVID19'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436292526751850496',
#        'indices': [117, 140],
#        'url': 'https://t.co/ni6iMMmUuu'}],
#      'user_mentions': []},
#     'favorite_count': 1035,
#     'favorited': False,
#     'geo': None,
#     'id': 1436292526751850496,
#     'id_str': '1436292526751850496',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 736,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'JUST IN - #BioNTech, which collaborates with #Pfizer, is set to request approval to use its #COVID19 vaccine in chi… https://t.co/ni6iMMmUuu',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Fri Jul 11 15:25:39 +0000 2008',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Observing world events unfold in the grand theater of our time.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'disclose.tv',
#          'expanded_url': 'https://www.disclose.tv',
#          'indices': [0, 23],
#          'url': 'https://t.co/O31NBmUmyw'}]}},
#      'favourites_count': 38565,
#      'follow_request_sent': False,
#      'followers_count': 616568,
#      'following': False,
#      'friends_count': 727,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 15392486,
#      'id_str': '15392486',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 3244,
#      'location': '',
#      'name': 'Disclose.tv',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/15392486/1502971451',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/898153945721339904/OFVCkPfR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/898153945721339904/OFVCkPfR_normal.jpg',
#      'profile_link_color': '3B94D9',
#      'profile_sidebar_border_color': '454545',
#      'profile_sidebar_fill_color': 'CFCFCF',
#      'profile_text_color': '2B2B2B',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'disclosetv',
#      'statuses_count': 2805,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/O31NBmUmyw',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @disclosetv: JUST IN - #BioNTech, which collaborates with #Pfizer, is set to request approval to use its #COVID19 vaccine in children as…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Fri Jun 19 21:21:54 +0000 2020',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Proud deplorable! 🇺🇸',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 33002,
#     'follow_request_sent': False,
#     'followers_count': 268,
#     'following': False,
#     'friends_count': 817,
#     'geo_enabled': False,
#     'has_extended_profile': False,
#     'id': 1274090000964091904,
#     'id_str': '1274090000964091904',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 1,
#     'location': '',
#     'name': 'TheNarrativeisCrumbling',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1274090000964091904/1611549117',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1414811207568138242/6jB6djFS_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1414811207568138242/6jB6djFS_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'kravMAGA1776',
#     'statuses_count': 9906,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:37 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1213606762357481473,
#       'id_str': '1213606762357481473',
#       'indices': [3, 15],
#       'name': 'Max Cooper MD',
#       'screen_name': '0MaxCooper0'},
#      {'id': 939091,
#       'id_str': '939091',
#       'indices': [97, 106],
#       'name': 'Joe Biden',
#       'screen_name': 'JoeBiden'},
#      {'id': 17137891,
#       'id_str': '17137891',
#       'indices': [123, 131],
#       'name': 'Walmart',
#       'screen_name': 'Walmart'},
#      {'id': 20793816,
#       'id_str': '20793816',
#       'indices': [132, 139],
#       'name': 'Amazon',
#       'screen_name': 'amazon'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307623645794308,
#    'id_str': '1436307623645794308',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 66,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 10 11:38:00 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436292872026918912',
#        'indices': [116, 139],
#        'url': 'https://t.co/VSzyjW73LM'}],
#      'user_mentions': [{'id': 939091,
#        'id_str': '939091',
#        'indices': [80, 89],
#        'name': 'Joe Biden',
#        'screen_name': 'JoeBiden'},
#       {'id': 17137891,
#        'id_str': '17137891',
#        'indices': [106, 114],
#        'name': 'Walmart',
#        'screen_name': 'Walmart'}]},
#     'favorite_count': 212,
#     'favorited': False,
#     'geo': None,
#     'id': 1436292872026918912,
#     'id_str': '1436292872026918912',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 66,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': "Something that's getting buried under the lede of the *Vaccine Mandate* is that @JoeBiden negotiated with @Walmart… https://t.co/VSzyjW73LM",
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Jan 04 23:43:01 +0000 2020',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': 'Dad, Husband, PA State Co-lead @cmteetoprotect, enthusiast @NLFD_org, Nether Providence Commissioner, Emergency Medicine Doc MD, US Navy Veteran.',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'committeetoprotect.org',
#          'expanded_url': 'https://committeetoprotect.org/',
#          'indices': [0, 23],
#          'url': 'https://t.co/5dah7pSOEF'}]}},
#      'favourites_count': 2273,
#      'follow_request_sent': False,
#      'followers_count': 1217,
#      'following': False,
#      'friends_count': 902,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 1213606762357481473,
#      'id_str': '1213606762357481473',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 15,
#      'location': 'Pennsylvania',
#      'name': 'Max Cooper MD',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1213606762357481473/1620159011',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1374895856663547905/zEJbOCsR_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1374895856663547905/zEJbOCsR_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': '0MaxCooper0',
#      'statuses_count': 2195,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/5dah7pSOEF',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': "RT @0MaxCooper0: Something that's getting buried under the lede of the *Vaccine Mandate* is that @JoeBiden negotiated with @Walmart @amazon…",
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jul 12 03:19:32 +0000 2012',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'Connecticut transplant sustaining in Virginia. VA10 resident. "The partitions were too low and Guillam\'s custard flowed into his meat."',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 9044,
#     'follow_request_sent': False,
#     'followers_count': 344,
#     'following': False,
#     'friends_count': 1695,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 633498687,
#     'id_str': '633498687',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 0,
#     'location': 'Virginia, USA',
#     'name': 'David Mathers',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/633498687/1475930253',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1186219591183282176/_4jDPXoC_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1186219591183282176/_4jDPXoC_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'DavidMathers4',
#     'statuses_count': 8664,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:36:36 +0000 2021',
#    'entities': {'hashtags': [{'indices': [115, 123], 'text': 'COVID19'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 785783685937295360,
#       'id_str': '785783685937295360',
#       'indices': [3, 19],
#       'name': 'Dr. Pramod Sawant',
#       'screen_name': 'DrPramodPSawant'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307618453082118,
#    'id_str': '1436307618453082118',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 90,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Fri Sep 10 09:39:15 +0000 2021',
#     'entities': {'hashtags': [{'indices': [94, 102], 'text': 'COVID19'}],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436262990093770754',
#        'indices': [116, 139],
#        'url': 'https://t.co/uT2j0Xp9oJ'}],
#      'user_mentions': []},
#     'favorite_count': 449,
#     'favorited': False,
#     'geo': None,
#     'id': 1436262990093770754,
#     'id_str': '1436262990093770754',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 90,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'I congratulate our Doctors, Nurses and Healthcare Workers for administering the first dose of #COVID19 vaccines to… https://t.co/uT2j0Xp9oJ',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Oct 11 10:06:44 +0000 2016',
#      'default_profile': False,
#      'default_profile_image': False,
#      'description': 'Chief Minister, Goa',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 1372,
#      'follow_request_sent': False,
#      'followers_count': 91130,
#      'following': False,
#      'friends_count': 303,
#      'geo_enabled': False,
#      'has_extended_profile': False,
#      'id': 785783685937295360,
#      'id_str': '785783685937295360',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 120,
#      'location': '',
#      'name': 'Dr. Pramod Sawant',
#      'notifications': False,
#      'profile_background_color': '000000',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/785783685937295360/1623135546',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1344851590457356288/O-8p3HFB_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1344851590457356288/O-8p3HFB_normal.jpg',
#      'profile_link_color': '19CF86',
#      'profile_sidebar_border_color': '000000',
#      'profile_sidebar_fill_color': '000000',
#      'profile_text_color': '000000',
#      'profile_use_background_image': False,
#      'protected': False,
#      'screen_name': 'DrPramodPSawant',
#      'statuses_count': 5719,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
# ...
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'retweet_count': 2,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'Joe Biden want all US workers to get vaccinated over #COVID19 \n\n@POTUS is gradually fulfilling his reasons of coming to power',
#     'truncated': False,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Wed Jan 28 16:59:47 +0000 2015',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 3436,
#      'follow_request_sent': False,
#      'followers_count': 1688,
#      'following': False,
#      'friends_count': 3440,
#      'geo_enabled': True,
#      'has_extended_profile': False,
#      'id': 3003503333,
#      'id_str': '3003503333',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 3,
#      'location': '',
#      'name': 'SENIOR ADVOCATE OF BIAFRA (SAB)',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3003503333/1583360219',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1424343457733259267/0Iv5v7eo_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1424343457733259267/0Iv5v7eo_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'COCOPACOPIACO1',
#      'statuses_count': 111715,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': 'RT @COCOPACOPIACO1: Joe Biden want all US workers to get vaccinated over #COVID19 \n\n@POTUS is gradually fulfilling his reasons of coming to…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Wed Jan 28 16:59:47 +0000 2015',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': '',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3436,
#     'follow_request_sent': False,
#     'followers_count': 1688,
#     'following': False,
#     'friends_count': 3440,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 3003503333,
#     'id_str': '3003503333',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 3,
#     'location': '',
#     'name': 'SENIOR ADVOCATE OF BIAFRA (SAB)',
#     'notifications': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3003503333/1583360219',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1424343457733259267/0Iv5v7eo_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1424343457733259267/0Iv5v7eo_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'COCOPACOPIACO1',
#     'statuses_count': 111715,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:35:59 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 997682274,
#       'id_str': '997682274',
#       'indices': [3, 18],
#       'name': 'Bryan Dawson',
#       'screen_name': 'BryanDawsonUSA'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307465348419587,
#    'id_str': '1436307465348419587',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 1388,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Sep 09 17:39:57 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1436021573308268555',
#        'indices': [125, 148],
#        'url': 'https://t.co/okCnXJGaUA'}],
#      'user_mentions': []},
#     'favorite_count': 2412,
#     'favorited': False,
#     'geo': None,
#     'id': 1436021573308268555,
#     'id_str': '1436021573308268555',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'en',
#     'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 1388,
#     'retweeted': False,
#     'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#     'text': 'Vaccines required for children:\n\nDiphtheria, Tetanus, &amp; Pertussis\nHaemophilus Influenzae Type B\nMeasles, Mumps, &amp; R… https://t.co/okCnXJGaUA',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Sat Dec 08 18:14:24 +0000 2012',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '“Radical Right=Radical Left=Radically Wrong.” Disinformation betrays all who fought for freedom #IAmJohnBrown #GunOwnerForGunReform #TrickleUp #StumpARepublican',
#      'entities': {'description': {'urls': []},
#       'url': {'urls': [{'display_url': 'youtube.com/BryanDawsonUSA',
#          'expanded_url': 'https://www.youtube.com/BryanDawsonUSA',
#          'indices': [0, 23],
#          'url': 'https://t.co/c7VkcaNY5C'}]}},
#      'favourites_count': 29757,
#      'follow_request_sent': False,
#      'followers_count': 94560,
#      'following': False,
#      'friends_count': 54097,
#      'geo_enabled': True,
#      'has_extended_profile': True,
#      'id': 997682274,
#      'id_str': '997682274',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 457,
#      'location': 'E PLURIBUS UNUM',
#      'name': 'Bryan Dawson',
#      'notifications': False,
#      'profile_background_color': 'C0DEED',
#      'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/997682274/1442695988',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1254478555339243520/PAfPDft7_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1254478555339243520/PAfPDft7_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'BryanDawsonUSA',
#      'statuses_count': 67155,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': 'https://t.co/c7VkcaNY5C',
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'RT @BryanDawsonUSA: Vaccines required for children:\n\nDiphtheria, Tetanus, &amp; Pertussis\nHaemophilus Influenzae Type B\nMeasles, Mumps, &amp; Rubel…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Mon May 09 00:08:41 +0000 2011',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '#resistance #getvaccinated #wearamask #dumptraitors',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 211630,
#     'follow_request_sent': False,
#     'followers_count': 3563,
#     'following': False,
#     'friends_count': 4996,
#     'geo_enabled': True,
#     'has_extended_profile': False,
#     'id': 295413810,
#     'id_str': '295413810',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 19,
#     'location': 'Florida',
#     'name': 'Paul Winters (He/Him)',
#     'notifications': False,
#     'profile_background_color': '642D8B',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#     'profile_background_tile': True,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/295413810/1612403536',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1211406261041999872/S5EEz8Lu_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1211406261041999872/S5EEz8Lu_normal.jpg',
#     'profile_link_color': 'FF0000',
#     'profile_sidebar_border_color': '65B0DA',
#     'profile_sidebar_fill_color': '7AC3EE',
#     'profile_text_color': '3D1957',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'pauly2coffees',
#     'statuses_count': 190700,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}},
#   {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Fri Sep 10 12:35:59 +0000 2021',
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': [{'id': 1353916548868665344,
#       'id_str': '1353916548868665344',
#       'indices': [3, 12],
#       'name': 'กองพันทหารช่างที่ 1 กองพลที่ 1 รักษาพระองค์',
#       'screen_name': 'Engi2418'}]},
#    'favorite_count': 0,
#    'favorited': False,
#    'geo': None,
#    'id': 1436307463733612550,
#    'id_str': '1436307463733612550',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'th',
#    'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#    'place': None,
#    'retweet_count': 193,
#    'retweeted': False,
#    'retweeted_status': {'contributors': None,
#     'coordinates': None,
#     'created_at': 'Thu Sep 09 08:06:17 +0000 2021',
#     'entities': {'hashtags': [],
#      'symbols': [],
#      'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#        'expanded_url': 'https://twitter.com/i/web/status/1435877206316617733',
#        'indices': [117, 140],
#        'url': 'https://t.co/vf2SNxhYeK'}],
#      'user_mentions': []},
#     'favorite_count': 194,
#     'favorited': False,
#     'geo': None,
#     'id': 1435877206316617733,
#     'id_str': '1435877206316617733',
#     'in_reply_to_screen_name': None,
#     'in_reply_to_status_id': None,
#     'in_reply_to_status_id_str': None,
#     'in_reply_to_user_id': None,
#     'in_reply_to_user_id_str': None,
#     'is_quote_status': False,
#     'lang': 'th',
#     'metadata': {'iso_language_code': 'th', 'result_type': 'recent'},
#     'place': None,
#     'possibly_sensitive': False,
#     'retweet_count': 193,
#     'retweeted': False,
#     'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#     'text': 'กองทัพบก โดย ช.พัน.1 พล.1 รอ. จัดรถครัวสนาม พร้อมกำลังพลจิตอาสา และ อาสาสมัครกิจการพลเรือน เขตพญาไท ต้มน้ำสมุนไพร 7… https://t.co/vf2SNxhYeK',
#     'truncated': True,
#     'user': {'contributors_enabled': False,
#      'created_at': 'Tue Jan 26 04:04:16 +0000 2021',
#      'default_profile': True,
#      'default_profile_image': False,
#      'description': '....',
#      'entities': {'description': {'urls': []}},
#      'favourites_count': 84,
#      'follow_request_sent': False,
#      'followers_count': 461,
#      'following': False,
#      'friends_count': 15,
#      'geo_enabled': False,
#      'has_extended_profile': True,
#      'id': 1353916548868665344,
#      'id_str': '1353916548868665344',
#      'is_translation_enabled': False,
#      'is_translator': False,
#      'lang': None,
#      'listed_count': 1,
#      'location': '',
#      'name': 'กองพันทหารช่างที่ 1 กองพลที่ 1 รักษาพระองค์',
#      'notifications': False,
#      'profile_background_color': 'F5F8FA',
#      'profile_background_image_url': None,
#      'profile_background_image_url_https': None,
#      'profile_background_tile': False,
#      'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1353916548868665344/1630644249',
#      'profile_image_url': 'http://pbs.twimg.com/profile_images/1353916821317984256/kMWyhxK5_normal.jpg',
#      'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1353916821317984256/kMWyhxK5_normal.jpg',
#      'profile_link_color': '1DA1F2',
#      'profile_sidebar_border_color': 'C0DEED',
#      'profile_sidebar_fill_color': 'DDEEF6',
#      'profile_text_color': '333333',
#      'profile_use_background_image': True,
#      'protected': False,
#      'screen_name': 'Engi2418',
#      'statuses_count': 327,
#      'time_zone': None,
#      'translator_type': 'none',
#      'url': None,
#      'utc_offset': None,
#      'verified': False,
#      'withheld_in_countries': []}},
#    'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#    'text': 'RT @Engi2418: กองทัพบก โดย ช.พัน.1 พล.1 รอ. จัดรถครัวสนาม พร้อมกำลังพลจิตอาสา และ อาสาสมัครกิจการพลเรือน เขตพญาไท ต้มน้ำสมุนไพร 7 นางฟ้า จำ…',
#    'truncated': False,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Jul 08 05:21:25 +0000 2021',
#     'default_profile': True,
#     'default_profile_image': False,
#     'description': 'หล่อ',
#     'entities': {'description': {'urls': []}},
#     'favourites_count': 3718,
#     'follow_request_sent': False,
#     'followers_count': 11,
#     'following': False,
#     'friends_count': 12,
#     'geo_enabled': False,
#     'has_extended_profile': True,
#     'id': 1413005181860548613,
#     'id_str': '1413005181860548613',
#     'is_translation_enabled': False,
#     'is_translator': False,
#     'lang': None,
#     'listed_count': 1,
#     'location': '',
#     'name': 'ลูฟี่หมวกฟาง',
#     'notifications': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1413338463470907399/VYVVHArw_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1413338463470907399/VYVVHArw_normal.jpg',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'I1PFbFztg0QXOnG',
#     'statuses_count': 3432,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': None,
#     'utc_offset': None,
#     'verified': False,
#     'withheld_in_countries': []}}]}

# %%
# current limits to followers/list endpoint
twitter.get_application_rate_limit_status()['resources']["search"]
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 179, 'reset': 1631278301}}

# %% [markdown]
# While the search API response is a dictionary, the `'statuses'` field contains the list of
# [Tweet Objects](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object)
# we're after.

# %%
search_tweets = search_response['statuses']
tweet = search_tweets[0]
tweet
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Sep 10 12:36:40 +0000 2021',
#  'entities': {'hashtags': [{'indices': [0, 8], 'text': 'Covid19'}],
#   'symbols': [],
#   'urls': [{'display_url': 'lalsace.fr/sante/2021/09/…',
#     'expanded_url': 'https://www.lalsace.fr/sante/2021/09/10/des-chercheurs-parviennent-a-detecter-le-virus-dans-la-sueur?utm_medium=Social&utm_source=Twitter#Echobox=1631263974-1',
#     'indices': [73, 96],
#     'url': 'https://t.co/RRn1RkwSmw'}],
#   'user_mentions': []},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1436307635368833031,
#  'id_str': '1436307635368833031',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'fr',
#  'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 0,
#  'retweeted': False,
#  'source': '<a href="https://www.echobox.com" rel="nofollow">Echobox</a>',
#  'text': '#Covid19 Des chercheurs parviennent à détecter le virus... dans la sueur https://t.co/RRn1RkwSmw',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Wed Apr 15 15:25:01 +0000 2009',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': "Toute l'actualité de la région",
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'lalsace.fr',
#       'expanded_url': 'https://lalsace.fr/',
#       'indices': [0, 23],
#       'url': 'https://t.co/JxV66VNa5G'}]}},
#   'favourites_count': 77,
#   'follow_request_sent': False,
#   'followers_count': 98194,
#   'following': False,
#   'friends_count': 734,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 31432523,
#   'id_str': '31432523',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 839,
#   'location': 'Alsace, France',
#   'name': "Journal L'Alsace",
#   'notifications': False,
#   'profile_background_color': 'ABB8C2',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/31432523/1453977186',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1284028649184911362/Tjbc8k8C_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1284028649184911362/Tjbc8k8C_normal.jpg',
#   'profile_link_color': '3B94D9',
#   'profile_sidebar_border_color': 'C6E2EE',
#   'profile_sidebar_fill_color': 'DAECF4',
#   'profile_text_color': '663B12',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'lalsace',
#   'statuses_count': 58112,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/JxV66VNa5G',
#   'utc_offset': None,
#   'verified': False,
#   'withheld_in_countries': []}}

# %% [markdown]
# Note that each tweet obtained from this API contains a `'user'` field -- this is a User Object for the user who created the tweet.

# %%
tweet['user']
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Wed Apr 15 15:25:01 +0000 2009',
#  'default_profile': False,
#  'default_profile_image': False,
#  'description': "Toute l'actualité de la région",
#  'entities': {'description': {'urls': []},
#   'url': {'urls': [{'display_url': 'lalsace.fr',
#      'expanded_url': 'https://lalsace.fr/',
#      'indices': [0, 23],
#      'url': 'https://t.co/JxV66VNa5G'}]}},
#  'favourites_count': 77,
#  'follow_request_sent': False,
#  'followers_count': 98194,
#  'following': False,
#  'friends_count': 734,
#  'geo_enabled': True,
#  'has_extended_profile': False,
#  'id': 31432523,
#  'id_str': '31432523',
#  'is_translation_enabled': False,
#  'is_translator': False,
#  'lang': None,
#  'listed_count': 839,
#  'location': 'Alsace, France',
#  'name': "Journal L'Alsace",
#  'notifications': False,
#  'profile_background_color': 'ABB8C2',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme17/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme17/bg.gif',
#  'profile_background_tile': True,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/31432523/1453977186',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1284028649184911362/Tjbc8k8C_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1284028649184911362/Tjbc8k8C_normal.jpg',
#  'profile_link_color': '3B94D9',
#  'profile_sidebar_border_color': 'C6E2EE',
#  'profile_sidebar_fill_color': 'DAECF4',
#  'profile_text_color': '663B12',
#  'profile_use_background_image': False,
#  'protected': False,
#  'screen_name': 'lalsace',
#  'statuses_count': 58112,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': 'https://t.co/JxV66VNa5G',
#  'utc_offset': None,
#  'verified': False,
#  'withheld_in_countries': []}

# %% [markdown]
# ## 4.2 Using a cursor to get more than 100 tweets from a search
#
# We can only fetch up to 100 tweets at a time from a single search API call:

# %%
# even with count=1000, we still get at most 100 tweets
search_response = twitter.search(q='#covid19', count=1000)
len(search_response['statuses'])
# Out:
# 100

# %% [markdown]
# In order to get more tweets from a search, we can make use of a cursor:

# %%
import itertools

NUM_TWEETS_TO_FETCH = 1000

cursor = twitter.cursor(twitter.search, q='#covid19', count=100, result_type='mixed')
search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
len(search_tweets)
# Out:
# 1000

# %%
import pandas as pd

# Search tweets
dict_ = {'user': [], 'date': [], 'text': [], 'favorite_count': []}
for tweet in search_tweets:
    dict_['user'].append(tweet['user']['screen_name'])
    dict_['date'].append(tweet['created_at'])
    dict_['text'].append(tweet['text'])
    dict_['favorite_count'].append(tweet['favorite_count'])
# Structure data in a pandas DataFrame for easier manipulation
df = pd.DataFrame(dict_)

# %%
df.head()
# Out:
#               user  ... favorite_count
# 0       DrEricDing  ...           5881
# 1    DrDenaGrayson  ...           7108
# 2       Minsa_Peru  ...           3837
# 3  DiabetesAsiaOrg  ...              0
# 4          PKJillu  ...              0
#
# [5 rows x 4 columns]

# %%
df.shape
# Out:
# (1000, 4)

# %% [markdown]
# Note the following:
# * The cursor object is a
# [generator](https://docs.python.org/3/tutorial/classes.html#generators),
# a type of iterator that "lazily" generates items. We use Python's `itertools.islice` in order to get up to a set number of items from this generator. The second argument passed to `islice` is the max number of tweets we want to fetch from the user.
# * Even though we want to get more than 100 tweets here, we provide the `count=100` argument. This tells the cursor to fetch the maximum number of tweets with each API call.
# * As documented in [Twitter's Search API documentation](https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html), specifying `result_type='mixed'` provides a mix of recent and popular tweets matching the query. If one desires a more "random" sample, you can specify `result_type='recent'`, but Twitter may provide fewer tweets than desired.

# %% [markdown]
# ## 4.3 API method rate limits
#
# Each API method has a *rate limit* imposed by Twitter, a limit on the number of function calls per 15-minute window. We can check on the rate limit status for this endpoint:

# %%
twitter.get_application_rate_limit_status()['resources']['search']
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 137, 'reset': 1631278301}}

# %% [markdown]
# These limits apply to the number of API *calls*, as opposed to the number of *items* fetched. This is why, when creating a cursor, we specify `count=` to fetch the maximum number of items per API call.

# %% [markdown]
# # 5.0 Creating social network graphs

# %% [markdown]
# In the remaining sections of this lesson, we're going to use NetworkX to create social networks from Twitter data. The examples are going to have users as nodes, so at a very basic level, we're going to do something like the following:

# %%
import networkx as nx

D = nx.DiGraph()

virus = twitter.show_user(screen_name='CoronavirusBra1')
author = twitter.show_user(screen_name='vacinacovidbr')

D.add_edge(virus['screen_name'], author['screen_name'], weight=1)

# %%
list(D.edges(data=True))
# Out:
# [('CoronavirusBra1', 'vacinacovidbr', {'weight': 1})]

# %% [markdown]
# Note that NetworkX will let us use the full user dictionaries as the node names, e.g. `D.add_edge(university, author)`. However, it is inconvenient to work with such a graph. More preferable is to use `screen_name` or `id` as the node names, and then use
# [node attributes](https://networkx.github.io/documentation/stable/tutorial.html#node-attributes)
# for the user profile data if desired.

# %% [markdown]
# # 6.0 Twitter retweet network

# %% [markdown]
# One fundamental interaction in the Twitter ecosystem is the "retweet" -- rebroadcasting another user's tweet to your followers. A tweet object returned by the API is a retweet if it includes a `'retweeted_status'`. We're going to fetch tweets matching a hashtag and create a retweet network of the conversation.

# %% [markdown]
# ## 6.1 Get some tweets

# %%
import itertools

NUM_TWEETS_TO_FETCH = 1000

cursor = twitter.cursor(twitter.search, q='#covid19', count=100, result_type='mixed')
search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
len(search_tweets)
# Out:
# 1000

# %%
search_tweets[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Sep 09 05:45:31 +0000 2021',
#  'entities': {'hashtags': [{'indices': [92, 100], 'text': 'COVID19'}],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1435841780457648128',
#     'indices': [116, 139],
#     'url': 'https://t.co/i8yt7Iyw1h'}],
#   'user_mentions': [{'id': 236998024,
#     'id_str': '236998024',
#     'indices': [62, 71],
#     'name': 'Comal ISD',
#     'screen_name': 'cisdnews'}]},
#  'favorite_count': 5881,
#  'favorited': False,
#  'geo': None,
#  'id': 1435841780457648128,
#  'id_str': '1435841780457648128',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 2794,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'Wow—“Every kindegarten teacher” at Kinder Ranch Elementary in @cisdnews tested positive for #COVID19. However, the… https://t.co/i8yt7Iyw1h',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Jan 10 11:01:33 +0000 2009',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Epidemiologist & health economist. Senior Fellow, @FAScientists. Former 16 yrs @Harvard. @JohnsHopkins alum. Health & social justice. COVID updates since Jan’20',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'fas.org/expert/eric-fe…',
#       'expanded_url': 'http://fas.org/expert/eric-feigl-ding/',
#       'indices': [0, 23],
#       'url': 'https://t.co/ipohSRjmIW'}]}},
#   'favourites_count': 201694,
#   'follow_request_sent': False,
#   'followers_count': 589443,
#   'following': False,
#   'friends_count': 9306,
#   'geo_enabled': True,
#   'has_extended_profile': True,
#   'id': 18831926,
#   'id_str': '18831926',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 6919,
#   'location': 'Washington DC & Virginia',
#   'name': 'Eric Feigl-Ding',
#   'notifications': False,
#   'profile_background_color': '3B94D9',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme19/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme19/bg.gif',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18831926/1613968996',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1296690786688479234/wflBN5Ks_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1296690786688479234/wflBN5Ks_normal.jpg',
#   'profile_link_color': '9266CC',
#   'profile_sidebar_border_color': 'FFFFFF',
#   'profile_sidebar_fill_color': 'F6FFD1',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'DrEricDing',
#   'statuses_count': 54906,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/ipohSRjmIW',
#   'utc_offset': None,
#   'verified': True,
#   'withheld_in_countries': []}}

# %% [markdown]
# ## 6.2 Filter retweets

# %% [markdown]
# Of the tweets we fetched, a subset will be retweets. Let's create a new list of just the retweets:

# %%
retweets = []
for tweet in search_tweets:
    if 'retweeted_status' in tweet:
        retweets.append(tweet)
len(retweets)
# Out:
# 781

# %%
# a retweet
retweets[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Sep 10 12:42:20 +0000 2021',
#  'entities': {'hashtags': [{'indices': [75, 83], 'text': 'COVID19'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 255147207,
#     'id_str': '255147207',
#     'indices': [3, 18],
#     'name': 'Paul Reid',
#     'screen_name': 'paulreiddublin'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1436309060589137948,
#  'id_str': '1436309060589137948',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 54,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Sep 10 07:48:40 +0000 2021',
#   'entities': {'hashtags': [{'indices': [55, 63], 'text': 'COVID19'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1436235157464391684',
#      'indices': [117, 140],
#      'url': 'https://t.co/5HyJepDeeK'}],
#    'user_mentions': []},
#   'favorite_count': 466,
#   'favorited': False,
#   'geo': None,
#   'id': 1436235157464391684,
#   'id_str': '1436235157464391684',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 54,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'text': 'Brighter news. Progress on a range of areas related to #COVID19. Today 90% of adults are fully vaccinated with 92.5… https://t.co/5HyJepDeeK',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Feb 20 19:37:17 +0000 2011',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'CEO of Health Service Executive.Loves Leitrim, Leeds Utd & Golf.Tweets in a personal capacity. For official comment and service queries, please contact @HSELive',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'hse.ie',
#        'expanded_url': 'http://www.hse.ie',
#        'indices': [0, 23],
#        'url': 'https://t.co/IUP6P8OuEA'}]}},
#    'favourites_count': 14589,
#    'follow_request_sent': False,
#    'followers_count': 80238,
#    'following': False,
#    'friends_count': 1236,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 255147207,
#    'id_str': '255147207',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': None,
#    'listed_count': 193,
#    'location': 'Ireland',
#    'name': 'Paul Reid',
#    'notifications': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/255147207/1611781194',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1317099954951901186/Z5nmO83i_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1317099954951901186/Z5nmO83i_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'paulreiddublin',
#    'statuses_count': 6420,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'https://t.co/IUP6P8OuEA',
#    'utc_offset': None,
#    'verified': True,
#    'withheld_in_countries': []}},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @paulreiddublin: Brighter news. Progress on a range of areas related to #COVID19. Today 90% of adults are fully vaccinated with 92.5% pa…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Thu Mar 04 15:51:41 +0000 2021',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Like old films, talking pictures, hairstylist, singer, love 💕 cats. study biology at tel-aviv University in viruses,vaccines & cells, data science inference.',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 22552,
#   'follow_request_sent': False,
#   'followers_count': 181,
#   'following': False,
#   'friends_count': 488,
#   'geo_enabled': False,
#   'has_extended_profile': True,
#   'id': 1367502948192956440,
#   'id_str': '1367502948192956440',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 0,
#   'location': '',
#   'name': 'Empress2222',
#   'notifications': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1403097270615150593/SFIAizwk_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1403097270615150593/SFIAizwk_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'Empress22223',
#   'statuses_count': 16666,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False,
#   'withheld_in_countries': []}}

# %% [markdown]
# ## 6.3 Create DiGraph

# %% [markdown]
# Each tweet in this list of retweets represents an edge in our network. <font color='red'>We're going to draw these edges in the direction of information flow</font>: from the retweeted user to the retweeter, the user doing the retweeting. Since a user can retweet another user more than once, we want this graph to be weighted, with the number of retweets as the weight.

# %%
import networkx as nx

D = nx.DiGraph()

for retweet in retweets:
    retweeted_status = retweet['retweeted_status']
    retweeted_sn = retweeted_status['user']['screen_name']
    retweeter_sn = retweet['user']['screen_name']
    
    # Edge direction: retweeted_sn -> retweeter_sn
    if D.has_edge(retweeted_sn, retweeter_sn):
        D.edges[retweeted_sn, retweeter_sn]['weight'] += 1
    else:
        D.add_edge(retweeted_sn, retweeter_sn, weight=1)

# %% [markdown]
# The edge addition logic here is to increase the edge weight by 1 if the edge exists, or else create the edge with weight 1 if it does not exist.
#
# When writing code such as this that refers multiple times to the same directed edge, make sure to be consistent with the edge direction.

# %% [markdown]
# ## 6.4 Analyze graph

# %% [markdown]
# Now that we have this graph, let's ask some questions about it.

# %% [markdown]
# ### 6.4.1 Most retweeted user

# %% [markdown]
# Since the edges are in the direction of information flow, out-degree gives us the number of other users retweeting a given user. We can get the user with highest out-degree using the built-in `max` function:

# %%
max(D.nodes, key=D.out_degree)
# Out:
# 'DrEricDing'

# %% [markdown]
# but we can get more context and information from the "top N" users:

# %%
from operator import itemgetter

sorted(D.out_degree(), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('DrEricDing', 24),
#  ('real_GGoswami', 17),
#  ('PIB_India', 14),
#  ('franfuentessv', 13),
#  ('ellymelly', 12)]

# %%
D.out_degree()
# Out:
# OutDegreeView({'paulreiddublin': 1, 'Empress22223': 0, 'Mediavenir': 7, 'brikieee': 0, 'TaisonBell': 1, 'perezoscar89': 0, 'sabahcovid': 1, 'pmrnabawan': 0, 'DrEricDing': 24, 'IowaLady_': 0, 'imUrB00gieman': 1, 'PuisSammy': 0, 'DataDrivenMD': 9, 'mccvic': 0, 'OmegaDiagnostic': 1, 'ChesRob': 0, 'EMA_News': 1, 'TheyaKTS': 0, 'tatoccf': 1, 'rafaelmesacordo': 0, 'disclosetv': 6, 'BullishHunter': 0, 'EdConwaySky': 3, 'Glez_Vecino': 0, 'MelillaGobierno': 1, 'hmohat01': 0, 'marklesher': 1, 'mikehun62': 0, 'dangainor': 1, 'ClimateDepot': 0, 'Alaa_elnajjar': 1, 'TelehealthBot': 0, 'JapenSabah': 1, 'myrabatchelder': 1, 'jjp117': 0, 'ImTheResistance': 1, 'menteabir': 0, 'sri50': 3, 'musicworldpeace': 0, 'alaninnc_owl': 0, 'jeangarr78': 1, 'R24Marie': 0, 'UNICEFIndia': 1, 'DiabetesAsiaOrg': 0, 'cubacooperaven': 1, 'KatrinVazquez': 0, 'MINSAPCuba': 1, 'dolysgmartinez': 0, 'hotline_sg': 1, 'vietnamlife': 0, 'ellymelly': 12, 'Photogoofer': 0, 'ZenzontleG': 1, 'jesussa53456527': 0, 'ThaiPBS': 12, 'Neenee_BR76': 0, 'MOH_TT': 1, 'Mikhel_MUFC': 0, 'NewsfirstSL': 1, 'adam_funama': 0, 'NC5PhilWilliams': 3, 'lynndukes': 0, 'grawminey': 1, 'zehammer': 0, 'SSalud_mx': 1, 'Ana_Tovar_S': 0, 'PSTRC_GM': 1, 'Sideshowbobdmd': 0, 'ItsGroundswell': 1, 'tonymckcopro': 0, 'bambi8333': 0, 'MieruchMario': 2, 'camerjeros1': 0, 'BMJ_Open': 1, 'UCT_ICHLibrary': 0, 'nirubanana1': 0, 'elpuntavui': 1, 'djrubenteixeira': 0, 'angiebellinger': 0, 'AlmendraPeleona': 0, 'bjp4kovai': 1, 'BALACBEBJP': 0, 'Aifa_ufficiale': 1, 'brunella85': 0, 'INDems': 2, 'carrybeyond': 0, 'drunkenTurtle99': 0, 'PsoeAytoPonfe': 1, 'AntonioVegaRod3': 0, 'Maria_Rad77': 1, 'BogochIsaac': 1, 'MolarFrog': 0, 'UfFs2VPWIDvwbhj': 0, 'SandraSentinel': 1, 'Jklmski56': 0, 'EckerleIsabella': 4, 'Colloseus_KTK': 0, 'Chandra508': 0, 'GettyImagesNews': 1, 'Sylvia_and_Bill': 0, 'KtylerWeeks': 0, 'profvrr': 1, 'kunaltungare': 0, 'mygovindia': 1, 'PKJillu': 0, 'COPEAsturias': 1, 'ateneojovellan1': 0, 'fabiofaria': 1, 'bonnieximena': 0, 'maverick33810': 0, 'dharmabum974': 0, 'PhTschopp': 1, 'novasatus': 0, 'NatNollid': 0, 'BOConnorMP': 1, 'alex12345ok': 0, 'Par_veen_': 0, 'GiovaQuez': 1, 'demian_online': 0, 'DiazCanelB': 3, 'B3rtoAl': 0, 'nicolasberrod': 1, 'lagrostA': 0, 'rb_covid19watch': 1, 'Gambia_bot': 0, 'drgregkelly': 7, 'Len_Lens_': 0, 'ACSQHC': 2, 'MartinLow88': 0, '9NewsAUS': 2, 'lovinglimbo': 0, 'contralinea': 1, 'SpiegelEmiliano': 0, 'MelaniaPlanete': 1, 'SenawangTV': 1, 'annasamirul_': 0, 'PIB_India': 14, 'ram_bhaktha': 0, 'PrayJashin': 7, 'Streamer_Boost': 0, 'VaccineChoiceCA': 2, 'mindstatex': 0, 'Sanju_Verma_': 3, 'pradeepbandaj1': 0, 'DrJacobsRad': 4, 'TraciVoice': 0, 'ObservatorioNi': 1, 'Trankerium1': 0, 'KCPubHealth': 1, 'wallsxfineIine': 0, 'DrPacoMoreno1': 3, 'ToniDavalos': 0, 'DnowMedia': 4, 'N0or_i': 0, 'ABSCBNNews': 1, 'tjmanotoc': 0, 'AnitaN1007': 0, 'weshoulddobeter': 1, 'MagicSilverFox': 0, 'otvnews': 1, 'RADHAMADHAB80': 0, 'Wiley_Chemistry': 1, 'TheNanotechNews': 0, 'prof_martens': 2, 'AndreasHoev': 0, 'NivedithaBhasin': 0, 'Claudiashein': 8, 'MiguelT62055461': 0, 'sami59': 0, 'aaigopairport': 2, 'viralvideovlogs': 0, 'DattRajeev': 0, 'micenet': 1, 'duchess80354553': 0, 'LeongWaiKitCNA': 9, 'MiO88192893': 0, 'NEJM': 2, 'roniilan': 0, 'franfuentessv': 13, 'Cristian214558': 0, 'COVIDNewsByMIB': 7, 'KingPraveena': 0, 'LaurenDownSouth': 0, 'DailyExpress_MY': 3, 'gideongys': 0, 'MucWizo': 0, 'LukaszukAB': 7, 'AdamBolt13': 0, 'reportrdotworld': 1, 'doysamia': 0, 'CovidFreePak': 2, 'hishamkhan82': 0, 'MariaKlSchmeink': 1, 'BSchepke': 0, 'Drs4CovidEthics': 8, 'nbby35yo': 0, 'RIZWIZ9': 0, 'ddc_riskcom': 7, 'Yimwanbb': 0, 'ILupobianco': 1, 'Enrico41274903': 0, 'laraf87': 3, 'ADRIANAAZZIAS': 0, 'Serviherramien6': 0, 'SudRadio': 1, 'DFabienne4': 0, 'Antonymus2': 0, 'CGTNOfficial': 2, 'Cryptonait': 0, 'HLGatell': 11, 'parora_2000': 0, 'wayneriderchick': 0, 'NST_Online': 1, 'WardahFaisal': 0, 'rhysthomas': 0, 'koko00052': 0, 'UNDPVietNam': 1, 'vando214654731': 0, 'Journal_GFS': 1, 'jessfanzo': 0 ...

# %% [markdown]
# In this piece of code, we take advantage of the fact that `D.out_degree()` returns a sequence of `(name, degree)` 2-tuples; specifying `key=itemgetter(1)` tells the `sorted` function to sort these 2-tuples by their value at index 1. Giving `reverse=True` tells the `sorted` function that we want this in descending order, and the `[:5]` at the end slices the first 5 items from the resulting list.
#
# However, this is a weighted graph! By default, `out_degree()` ignores the edge weights. We can get out-strength by telling the `out_degree()` function to take into account the edge weight:

# %%
sorted(D.out_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('DrEricDing', 26),
#  ('real_GGoswami', 17),
#  ('PIB_India', 16),
#  ('DnowMedia', 15),
#  ('ellymelly', 13)]

# %% [markdown]
# In some cases these two results will be the same, namely if none of these users has been retweeted multiple times by the same user. Depending on your use case, you may or may not wish to take the weights into account.

# %% [markdown]
# ### 6.4.2 Anomaly detection

# %% [markdown]
# One type of social media manipulation involves accounts that create very little original content, instead "spamming" retweets of any and all content in a particular conversation. Can we detect any users doing significantly more retweeting than others? Let's look at the top N retweeters:

# %%
sorted(D.in_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('viralvideovlogs', 17),
#  ('Nasreen_wani', 5),
#  ('TasawarDaniyal', 5),
#  ('N0or_i', 4),
#  ('MichaelWBate', 4)]

# %% [markdown]
# ### 6.4.3 Connectivity

# %% [markdown]
# We can ask if the tweets obtained by the search represent one large conversation or many small conversations; broadly speaking, each weakly-connected component represents a conversation.

# %%
nx.is_weakly_connected(D)
# Out:
# False

# %%
nx.number_weakly_connected_components(D)
# Out:
# 357

# %% [markdown]
# ### 6.4.4 Drawing

# %% [markdown]
# We can try to draw this graph with the nodes sized by their out-strength:

# %%
node_sizes = [D.out_degree(n, weight='weight') * 50 for n in D.nodes]

# %matplotlib inline
nx.draw(D, node_size=node_sizes)

# %% [markdown]
# Note that in this simplistic drawing, nodes with zero out-strength are not drawn on the diagram because their size is 0. This suits us fine; only the users who have been retweeted are drawn here.

# %% [markdown]
# # 7.0 Twitter mention network

# %% [markdown]
# Another Twitter interaction between users occurs when one user mentions another in a tweet by their @screen_name. As an example, consider the following hypothetical tweet from @osome_iu:
#
# > Check out the new research from @IUSICE and @USC_ISI https://...
#
# From this tweet we would create two edges:
#
#     ('osome_iu', 'IUSICE')
#     ('osome_iu', 'USC_ISI')
#
# It's up to us which direction we draw these edges, but we should be consistent. In this example, we will draw edges in the direction of attention flow: @osome_iu is giving attention to @IUSICE and @USC_ISI.

# %% [markdown]
# ## 7.1 Get some tweets

# %%
import itertools

NUM_TWEETS_TO_FETCH = 1000

cursor = twitter.cursor(twitter.search, q='covid19', count=100, result_type='mixed')
search_tweets = list(itertools.islice(cursor, NUM_TWEETS_TO_FETCH))
len(search_tweets)
# Out:
# 1000

# %% [markdown]
# ## 7.2 Create DiGraph
#
# It's not necessary to first filter out tweets containing user mentions due to a feature of
# [Tweet Objects](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object):
# every tweet has
# [Entities](https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/entities-object#entitiesobject)
# which always contains a `'user_mentions'` list, even if that list is empty. Since a tweet may mention more than one user, we need a nested for-loop.

# %%
search_tweets[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Sep 09 00:44:59 +0000 2021',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1435766147304108034',
#     'indices': [117, 140],
#     'url': 'https://t.co/w8qJlilNqn'}],
#   'user_mentions': []},
#  'favorite_count': 16150,
#  'favorited': False,
#  'geo': None,
#  'id': 1435766147304108034,
#  'id_str': '1435766147304108034',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'es',
#  'metadata': {'iso_language_code': 'es', 'result_type': 'popular'},
#  'place': None,
#  'retweet_count': 5564,
#  'retweeted': False,
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'El trombo entre un millón de vacunados.\n\nEl vacunado que muere por Covid19 entre los millones que evitan contagiars… https://t.co/w8qJlilNqn',
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Feb 25 21:09:51 +0000 2012',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Humor y Divulgación sanitaria. Colaboro en 🎙@rne @RadioGalega 📺 @Antena3com y ✍🏼 @elmundoes. Escritor @penguinlibros. Enfermero en🏥.👨🏻\u200d⚕️Héctor Castiñeira',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'instabio.cc/EnfermeraSatur…',
#       'expanded_url': 'https://instabio.cc/EnfermeraSaturada',
#       'indices': [0, 23],
#       'url': 'https://t.co/EG9wjvYB3I'}]}},
#   'favourites_count': 34158,
#   'follow_request_sent': False,
#   'followers_count': 178579,
#   'following': False,
#   'friends_count': 719,
#   'geo_enabled': True,
#   'has_extended_profile': True,
#   'id': 503554266,
#   'id_str': '503554266',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': None,
#   'listed_count': 696,
#   'location': 'Lugo - Madrid (Spain)',
#   'name': 'Enfermera Saturada 🦖',
#   'notifications': False,
#   'profile_background_color': '000000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme13/bg.gif',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme13/bg.gif',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/503554266/1601884439',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1406904844313636865/RBirm5lC_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1406904844313636865/RBirm5lC_normal.jpg',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': '000000',
#   'profile_text_color': '000000',
#   'profile_use_background_image': False,
#   'protected': False,
#   'screen_name': 'EnfrmraSaturada',
#   'statuses_count': 26791,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': 'https://t.co/EG9wjvYB3I',
#   'utc_offset': None,
#   'verified': True,
#   'withheld_in_countries': []}}

# %%
import networkx as nx

D = nx.DiGraph()

for tweet in search_tweets:
    tweet_sn = tweet['user']['screen_name']
    for user_mention in tweet['entities']['user_mentions']:
        mentioned_sn = user_mention['screen_name']
        
        my_edge = (tweet_sn, mentioned_sn)
        if D.has_edge(*my_edge):
            D.edges[my_edge]['weight'] += 1
        else:
            D.add_edge(*my_edge, weight=1)

# %% [markdown]
# ## 7.3 Analyze graph

# %% [markdown]
# Now that we have this graph, let's ask some questions about it.

# %% [markdown]
# ### 7.3.1 Most  popular users

# %% [markdown]
# Since these edges are in the direction of attention flow, in-degree gives us the number of other users mentioning a given user. We can get the user with highest in-degree using the built-in `max` function:

# %%
max(D.nodes, key=D.in_degree)
# Out:
# 'thestandardth'

# %% [markdown]
# but we can get more context and information from the "top N" users:

# %%
from operator import itemgetter

sorted(D.in_degree(), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('thestandardth', 25),
#  ('j_mcelroy', 18),
#  ('ellymelly', 17),
#  ('Minsa_Peru', 16),
#  ('HLGatell', 12)]

# %% [markdown]
# By specifying `weight='weight'` we can instead get the top 5 users by in-strength instead of in-degree:

# %%
sorted(D.in_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('thestandardth', 26),
#  ('ellymelly', 19),
#  ('j_mcelroy', 18),
#  ('Minsa_Peru', 16),
#  ('HLGatell', 12)]

# %% [markdown]
# In some cases these two results will be the same, namely if none of these users has been mentioned multiple times by the same user. Depending on your use case, you may or may not wish to take the weights into account.

# %% [markdown]
# ### 7.3.2 Conversation drivers

# %% [markdown]
# A user mentioning many others in a conversation may be "driving" the conversation and trying to include others in the dialogue. It could also be spam. Let's see who is doing the most mentioning here:

# %%
sorted(D.out_degree(weight='weight'), key=itemgetter(1), reverse=True)[:5]
# Out:
# [('viralvideovlogs', 16),
#  ('ArmandoLaritza', 9),
#  ('BauzaCuba', 9),
#  ('DeanLowry', 8),
#  ('na_cpl', 8)]

# %% [markdown]
# ### 7.3.3 Connectivity

# %% [markdown]
# We can ask if the tweets obtained by the search represent one large conversation or many small conversations; broadly speaking, each weakly-connected component represents a conversation.

# %%
nx.is_weakly_connected(D)
# Out:
# False

# %%
nx.number_weakly_connected_components(D)
# Out:
# 406

# %% [markdown]
# ### 7.3.4 Drawing

# %% [markdown]
# We can try to draw this graph with the nodes sized by their in-strength:

# %%
node_sizes = [D.in_degree(n, weight='weight') * 50 for n in D.nodes]

# %matplotlib inline
nx.draw(D, node_size=node_sizes)

# %% [markdown]
# Note that in this simplistic drawing, nodes with zero in-strength are not drawn on the diagram because their size is 0. This suits us fine; only the users who have been mentioned are drawn here.

# %%
nx.write_graphml(D, 'covid19.graphml')
